# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("./OriginalData.csv")
df.head()
# Out:
#    Unnamed: 0  FirstObjectDistance_X  FirstObjectDistance_Y  \
# 0           0                   8211                   1444
# 1           1                   8208                   1443
# 2           2                   8211                   1444
# 3           3                   8209                   1445
# 4           4                   8209                   1445
#
#    SecondObjectDistance_X  SecondObjectDistance_Y  ThirdObjectDistance_X  \
# 0                    5455                   -1153                   3103
# 1                    5455                   -1153                   3102
# 2                    5453                   -1160                   3104
# 3                    5452                   -1166                   3104
# 4                    5452                   -1167                   3106
#
#    ThirdObjectDistance_Y  FourthObjectDistance_X  FourthObjectDistance_Y  \
# 0                  -1237                   12024                    1715
# ...

# %%
df[df['FirstObjectDistance_X']==0].head()
# Out:
#      Unnamed: 0  FirstObjectDistance_X  FirstObjectDistance_Y  \
# 275         275                      0                      0
# 276         276                      0                      0
#
#      SecondObjectDistance_X  SecondObjectDistance_Y  ThirdObjectDistance_X  \
# 275                    4874                   -1738                   6246
# 276                    4837                   -1739                   6214
#
#      ThirdObjectDistance_Y  FourthObjectDistance_X  FourthObjectDistance_Y  \
# 275                   1452                    5600                    1737
# 276                   1435                    5559                    1736
#
#      VehicleSpeed  FirstObjectSpeed_X  FirstObjectSpeed_Y  \
# 275          1080                   0                   0
# 276          1079                   0                   0
#
#      SecondObjectSpeed_X  SecondObjectSpeed_Y  ThirdObjectSpeed_X  \
# 275                -1105                  -71               -1074
# ...

# %%
plt.subplot(1, 2, 1)

plt.scatter(df['FirstObjectDistance_Y'], df['FirstObjectDistance_X'], c=color_gradient, cmap='viridis')
plt.xlabel('X')
plt.ylabel('Y')

plt.title('Distance Scatter Plot')

plt.subplot(1, 2, 2)

X_speed = df['FirstObjectSpeed_X']
Y_speed = df['FirstObjectSpeed_Y']
plt.scatter(X_speed, Y_speed, c=color_gradient, cmap='viridis')
plt.xlabel('X Speed')
plt.ylabel('Y Speed')
plt.title('Speed Scatter Plot')
plt.colorbar().set_label('Data Index')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/kristof/Desktop/Hackathon20230929/CodeLikeABosch2023/objects_rel_to_car.ipynb Cell 4 line 3
#       <a href='vscode-notebook-cell:/home/kristof/Desktop/Hackathon20230929/CodeLikeABosch2023/objects_rel_to_car.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> plt.subplot(1, 2, 1)
# ----> <a href='vscode-notebook-cell:/home/kristof/Desktop/Hackathon20230929/CodeLikeABosch2023/objects_rel_to_car.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> plt.scatter(df['FirstObjectDistance_Y'], df['FirstObjectDistance_X'], c=color_gradient, cmap='viridis')
#       <a href='vscode-notebook-cell:/home/kristof/Desktop/Hackathon20230929/CodeLikeABosch2023/objects_rel_to_car.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> plt.xlabel('X')
# ...

# %%
color_gradient = np.linspace(0, 1, len(df['FirstObjectDistance_X']))
plt.scatter(df['FirstObjectDistance_Y'], df['FirstObjectDistance_X'], c=color_gradient, cmap='viridis')
colorbar = plt.colorbar()
colorbar.set_label('Data Index')
plt.xlabel('X')
plt.ylabel('Y')
plt.plot()
# Out:
# []

# %%
color_gradient = np.linspace(0, 1, len(df['SecondObjectDistance_X']))
plt.scatter(df['SecondObjectDistance_Y'], df['SecondObjectDistance_X'], c=color_gradient, cmap='viridis')
colorbar = plt.colorbar()
colorbar.set_label('Data Index')

# %%
color_gradient = np.linspace(0, 1, len(df['ThirdObjectDistance_X']))
plt.scatter(df['ThirdObjectDistance_Y'], df['ThirdObjectDistance_X'], c=color_gradient, cmap='viridis')
colorbar = plt.colorbar()
colorbar.set_label('Data Index')

# %%
color_gradient = np.linspace(0, 1, len(df['FourthObjectDistance_X']))
plt.scatter(df['FourthObjectDistance_Y'], df['FourthObjectDistance_X'], c=color_gradient, cmap='viridis')
colorbar = plt.colorbar()
colorbar.set_label('Data Index')
